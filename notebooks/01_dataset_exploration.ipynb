# %%
import sys
print(sys.executable)
# Out:
# d:\study\mtech\ocr\Ancient_Indic_OCR\venv\Scripts\python.exe

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.zeros((200, 400, 3), dtype=np.uint8)

plt.imshow(img)
plt.title("Test Image")
plt.axis("off")
plt.show()
